# %%
import ipywidgets as widgets
from IPython.display import display

widgets.Dropdown(
    options=["A", "B", "C"],
    value="A",
    description="Choice:"
)
# Out:
# Dropdown(description='Choice:', options=('A', 'B', 'C'), value='A')
